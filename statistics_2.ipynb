# %% [markdown]
# <b>Задание 1.</b> Из партии батареек с номинальным напряжением 12 В наугад выбрано семь штук. Согласно показаниям высокоточного вольтметра, фактически выдаваемое ими напряжение составило: 12,9; 11,6; 13,5; 13,9; 12,1; 11,9; 13,0 В соответственно. Можно ли считать, что среднее напряжение действительно равно 12 В?

# %% [markdown]
# Нулевая гипотеза (𝐻0): Среднее напряжение батареек равно 12В.
# Альтернативная гипотеза (H1): Среднее навпряжение батареек не равно 12В.

# %%
import numpy as np
from scipy import stats

# %%
x = np.array([12.9, 11.6, 13.5, 13.9, 12.1, 11.9, 13])

# %%
mu0 = 12

# %%
df = len(x)-1
student = stats.t(df)
T = (df)**0.5*(x.mean()-mu0)/x.std()
P = student.cdf(T)
print('Statistic:', T, 'p-value', P)
# Out:
# Statistic: 2.1578017974978794 p-value 0.9628490489471885

# %% [markdown]
# По таблице t-распределения для 6 степеней свободы и уровня значимсоти 0.05 критическое значнение t равно 2.45. Полученная t-статистика меньше критического значения, поэтому мы не отвергам нулевую гипотезу о том, что среднее напряжение равно 12В. К тому же значение p-value больше 0.05, что не позволяет нам отврегать нулевую гипотезу.

# %% [markdown]
# <b>Задание 2.</b> Есть два различных метода определения процентного содержания жира в мясе. Доля жира для 10 образцов мяса была определена каждым из двух методов. Позволяют ли полученные результаты сделать вывод о том, что один метод даёт в среднем более высокие показания, чем другой?

# %% [markdown]
# Нулевая гипотеза (H0): Средние значения двух методов равны (разница равна 0).
# Альтернативная гипотеза (H1): Среднее значение Метода I больше, чем Метода II.

# %%
x = np.array([23.1, 23.2, 26.5, 26.6, 27.1, 48.3, 40.5, 25, 38.4, 23.5])
y = np.array([22.7, 23.6, 27.1, 27.4, 27.4, 46.8, 40.4, 24.9, 38.1, 23.8])

z = x-y

# %%
df = len(x)-1
student = stats.t(df)
T = (df)**0.5*z.mean()/z.std()
P = student.cdf(T)
print('Statistic:', T, 'p-value', P)
# Out:
# Statistic: 1.715488497867803e-15 p-value 0.5000000000000007

# %% [markdown]
# Поскольку p-value значительно больше стандартного уровня значимости 0.05, мы не отвергаем нулевую гипотезу.
# Нет статистически значимых различий в средних показателях двух методов определения процентного содержания жира в мясе.

# %% [markdown]
# <b>Задание 3.</b> Для проверки гипотезы о том, что жители городов имеют в среднем более высокое систолическое артериальное давление, чем жители сельской местности, было проведено обследование 10 горожан и 9 жителей села примерно одного возраста. Получены следующие данные об уровне давления для горожан: 132, 111, 119, 138, 200, 131, 138, 170, 159, 140; для селян: 115, 190, 127, 155, 148, 121, 116, 121, 197. Можно ли считать верной выдвинутую гипотезу на уровне значимости 0,05?

# %% [markdown]
# Нулевая гипотеза (H0): Средние значения артериального давление у горожан и у сельских жителей равны (разница между средними значениями равна 0).
# Альтернативная гипотеза (H1): Среднее значение артериального давление у горожан больше, чем у сельских жителей.

# %%
x = np.array([132, 111, 119, 138, 200, 131, 138, 170, 159, 140])
y = np.array([115, 190, 127, 155, 148, 121, 116, 121, 197])

# %%
dfx = len(x)-1
dfy = len(y)-1
student = stats.t(dfx+dfy-2)
T = (x.mean()-y.mean())/(x.std()**2/dfx + y.std()**2/dfy)**0.5
P = student.cdf(T)
print('Statistic:', T, 'p-value', P)
# Out:
# Statistic: 0.03479498734072727 p-value 0.513648985616522

# %% [markdown]
# Значение p_value больше 0.05, то у нас нет достаточно оснований для того, чтобы отвергнуть нулевую гипотезу. То есть, разница в давлении статистически незначима.

# %% [markdown]
# <b>Задание 4.</b> Известно, что 52% новорождённых детей — мальчики, а 48% — девочки. В случайной выборке из 5 000 человек в возрасте от 30 до 60 лет мужчин оказалось 2 500. Можно ли на уровне значимости 0,05 считать, основываясь на этих данных, что смертность среди мужчин и женщин одинакова?

# %% [markdown]
# Нулевая гипотеза (H0): Смертность среди мужчин и женщин одинакова.
# Альтернативная гипотеза (H1): Смертность среди мужчин и женщин различна.

# %%
from scipy.stats import chisquare

# Наблюдаемые частоты
observed = np.array([2500, 2500])
# Ожидаемые частоты
expected = np.array([0.52 * 5000, 0.48 * 5000])

# Выполнение теста хи-квадрат
T, P = chisquare(observed, f_exp=expected)
print('Statistic:', T, 'p-value', P)
# Out:
# Statistic: 8.012820512820513 p-value 0.004644733942292499

# %% [markdown]
# Значение p_value меньше уровня значимости 0.05, поэтому мы отвергаем нулевую гипотезу.
# На уровне значимости 0.05 мы можем считать, что смертность среди мужчин и женщин различается.

# %% [markdown]
# <b>Задание 5.</b> В первом эксперименте для сравнения двух средних X1=17, X2=16 применялся t-критерий Стьюдента, и эти различия оказались значимы (p = 0, 001).
#
# Во втором исследовании, также при помощи t - критерия, сравнивались два средних X1=17, X2=36, и эти различия не значимы при p = 0,8. В чем может быть причина таких результатов, при условии, что нулевая и альтернативная гипотезы в обоих случаях одинаковы?

# %% [markdown]
# * t-критерий Стьюдента чувствителен к размеру выборок. Большие выборки могут давать более точные оценки и, следовательно, более значимые результаты.
#
# * Если дисперсия в одной из выборок значительно больше, это может привести к тому, что различия между средними значениями будут считаться незначимыми.
#
# * Если данные не следуют нормальному распределению, это может влиять на результаты t-критерия. t-критерий Стьюдента предполагает нормальное распределение данных.
